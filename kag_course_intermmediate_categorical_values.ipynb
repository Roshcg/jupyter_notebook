# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv('/home/m1049296/Downloads/train.csv', index_col='Id')

# %%
X_test = pd.read_csv('/home/m1049296/Downloads/test.csv', index_col='Id')

# %%
X.dropna(axis=0, subset=['SalePrice'], inplace=True)

# %%
y = X.SalePrice

# %%
X.drop('SalePrice', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_319998/3391199089.py in <module>
# ----> 1 X.drop('SalePrice', axis=1, inplace=True)
#
# NameError: name 'X' is not defined

# %%
miss_cols = [col for col in X.columns if X[col].isnull().any()]

# %%
X.drop(miss_cols, axis=1, inplace=True)

# %%
X_test.drop(miss_cols, axis=1, inplace=True)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=1)

# %%
X_train.head()
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 922           90       RL     8777   Pave      Reg         Lvl    AllPub
# 521          190       RL    10800   Pave      Reg         Lvl    AllPub
# 402           20       RL     8767   Pave      IR1         Lvl    AllPub
# 281           60       RL    11287   Pave      Reg         Lvl    AllPub
# 1402          60       RL     7415   Pave      IR1         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# Id                                     ...
# 922     Inside       Gtl      Edwards  ...          70             0
# 521     Inside       Gtl      OldTown  ...         114           210
# 402     Inside       Gtl      CollgCr  ...           0             0
# 281     Inside       Gtl      SawyerW  ...          84             0
# 1402    Inside       Gtl      Gilbert  ...          75             0
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor()
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_absolute_error(y_valid, preds)

# %%
drop_X_train = X_train.select_dtypes(exclude=['object'])
drop_X_valid = X_valid.select_dtypes(exclude=['object'])

# %%
print('without drop')
print(score_dataset(drop_X_train, drop_X_valid, y_train, y_valid))
# Out:
# without drop
# 16788.148139269408

# %%
object_col = [col for col in X_train.columns if X_train[col].dtype == 'object']

# %%
good_obj_col = [col for col in object_col if set(X_valid[col]).issubset(X_train[col])]

# %%
object_col
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
good_obj_col
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
bad_obj_col = list(set(object_col) - set(good_obj_col))

# %%
bad_obj_col
# Out:
# ['RoofMatl', 'Exterior1st', 'HeatingQC']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
obj_X_train = X_train.drop(bad_obj_col, axis=1)
obj_X_valid = X_valid.drop(bad_obj_col, axis=1)

# %%
obj_X_train
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 922           90       RL     8777   Pave      Reg         Lvl    AllPub
# 521          190       RL    10800   Pave      Reg         Lvl    AllPub
# 402           20       RL     8767   Pave      IR1         Lvl    AllPub
# 281           60       RL    11287   Pave      Reg         Lvl    AllPub
# 1402          60       RL     7415   Pave      IR1         Lvl    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 716           20       RL    10140   Pave      Reg         Lvl    AllPub
# 906           20       RL     9920   Pave      Reg         Lvl    AllPub
# 1097          70       RM     6882   Pave      Reg         Lvl    AllPub
# 236          160       RM     1680   Pave      Reg         Lvl    AllPub
# 1062          30  C (all)    18000   Grvl      Reg         Low    AllPub
#
#      LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# ...

# %%
ord_encoder = OrdinalEncoder()
obj_X_train[good_obj_col] = ord_encoder.fit_transform(X_train[good_obj_col])
obj_X_valid[good_obj_col] = ord_encoder.transform(X_valid[good_obj_col])

# %%
obj_X_train
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 922           90       RL     8777   Pave      Reg         Lvl    AllPub
# 521          190       RL    10800   Pave      Reg         Lvl    AllPub
# 402           20       RL     8767   Pave      IR1         Lvl    AllPub
# 281           60       RL    11287   Pave      Reg         Lvl    AllPub
# 1402          60       RL     7415   Pave      IR1         Lvl    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 716           20       RL    10140   Pave      Reg         Lvl    AllPub
# 906           20       RL     9920   Pave      Reg         Lvl    AllPub
# 1097          70       RM     6882   Pave      Reg         Lvl    AllPub
# 236          160       RM     1680   Pave      Reg         Lvl    AllPub
# 1062          30  C (all)    18000   Grvl      Reg         Low    AllPub
#
#      LotConfig LandSlope Neighborhood  ... OpenPorchSF EnclosedPorch  \
# ...

# %%
low_cardinality_cols = [col for col in X_train.columns if X_train[col].nunique() < 10]

# %%
low_cardinality_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallCond',
#  'RoofStyle',
#  'RoofMatl',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'Functional',
#  'Fireplaces',
#  'GarageCars',
#  'PavedDrive',
#  'PoolArea',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %%
from sklearn.preprocessing import OneHotEncoder

# Use as many lines of code as you need!
oh_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)

cat_col_train = pd.DataFrame(oh_encoder.fit_transform(X_train[low_cardinality_cols]))
cat_col_valid = pd.DataFrame(oh_encoder.transform(X_valid[low_cardinality_cols]))

cat_col_train.index = X_train.index
cat_col_valid.index = X_valid.index

num_X_train = X_train.drop(low_cardinality_cols, axis=1)
num_X_valid = X_valid.drop(low_cardinality_cols, axis=1)

OH_X_train = pd.concat([num_X_train, cat_col_train], axis=1)
OH_X_valid = pd.concat([num_X_valid, cat_col_valid], axis=1)

# %%
OH_X_train
# Out:
#       MSSubClass  LotArea Neighborhood  OverallQual  YearBuilt  YearRemodAdd  \
# Id
# 922           90     8777      Edwards            5       1900          2003
# 521          190    10800      OldTown            4       1900          2000
# 402           20     8767      CollgCr            7       2005          2005
# 281           60    11287      SawyerW            7       1989          1989
# 1402          60     7415      Gilbert            6       2004          2004
# ...          ...      ...          ...          ...        ...           ...
# 716           20    10140       NWAmes            6       1974          1974
# 906           20     9920        NAmes            5       1954          1954
# 1097          70     6882       IDOTRR            6       1914          2006
# 236          160     1680       BrDale            6       1971          1971
# 1062          30    18000       IDOTRR            3       1935          1950
#
# ...

# %%
OH_X_train.shape
# Out:
# (1168, 202)
