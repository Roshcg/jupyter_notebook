# %%
import pandas as pd

# %%
reviews = pd.read_csv("/home/m1049296/Downloads/rosh/jupyterr/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews.shape
# Out:
# (129971, 13)

# %%
reviews.groupby('country').head()
# Out:
#                        country  \
# 0                        Italy
# 1                     Portugal
# 2                           US
# 3                           US
# 4                           US
# ...                        ...
# 81814              Switzerland
# 83622                    India
# 96759   Bosnia and Herzegovina
# 109989                   China
# 110246                   Egypt
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 81814   This wine has a bouquet of tart cherry with a ...
# 83622   Pineapple, grapefruit, and apricot show bright...
# ...

# %%
best_rating_per_price = reviews.groupby('price')['points'].max()

# %%
best_rating_per_price
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
reviews.groupby('variety').price.agg([min,max]).sort_values(by=['min', 'max'], ascending=False).head(20)
# Out:
#                               min    max
# variety
# Ramisco                     495.0  495.0
# Terrantez                   236.0  236.0
# Francisa                    160.0  160.0
# Rosenmuskateller            150.0  150.0
# Tinta Negra Mole            112.0  112.0
# Pignolo                      70.0   70.0
# Syrah-Cabernet Franc         60.0   69.0
# Garnacha-Cariñena            57.0   57.0
# Doña Blanca                  53.0   53.0
# Cercial                      50.0   50.0
# Mavrotragano                 50.0   50.0
# Sercial                      50.0   50.0
# Pugnitello                   49.0   49.0
# Malbec-Cabernet              45.0  165.0
# Tinta del Pais               45.0   50.0
# Touriga                      45.0   46.0
# Babosa Negro                 45.0   45.0
# Cabernet Sauvignon-Barbera   45.0   45.0
# Syrah-Grenache-Viognier      45.0   45.0
# Tinta Madeira                45.0   45.0

# %%
reviews.groupby(['country', 'variety']).variety.count().sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir                  9885
#          Cabernet Sauvignon          7315
#          Chardonnay                  6801
# France   Bordeaux-style Red Blend    4725
# Italy    Red Blend                   3624
#                                      ...
# Mexico   Cinsault                       1
#          Grenache                       1
#          Merlot                         1
#          Rosado                         1
# Uruguay  White Blend                    1
# Name: variety, Length: 1612, dtype: int64

# %%
reviews.region_1.fillna('Unknown').value_counts()
# Out:
# Unknown                    21247
# Napa Valley                 4480
# Columbia Valley (WA)        4124
# Russian River Valley        3091
# California                  2629
#                            ...
# Lamezia                        1
# Trentino Superiore             1
# Grave del Friuli               1
# Vin Santo di Carmignano        1
# Paestum                        1
# Name: region_1, Length: 1230, dtype: int64
